# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier

# %%
data_pd = pd.read_csv('titanic_preprocessed.csv')
data_pd = data_pd.sort_values(by = 'PassengerId')
test_pd = data_pd[data_pd['Survived'].isna()]
test_pd['PassengerId'] = test_pd['PassengerId'] + 1
test_pd_tmp = test_pd.drop(columns = ['Survived','PassengerId'])
display(data_pd)
display(test_pd)
# Out:
# /tmp/ipykernel_712188/1356244638.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_pd['PassengerId'] = test_pd['PassengerId'] + 1
#       PassengerId  Pclass  SibSp  Parch  Fare_Bin  Num_family  Age_Bin  Sex_0  \
# 263             0       2      1      0         0           2        2  False
# 264             1       0      1      0         1           2        3   True
# 265             2       2      0      0         0           0        2   True
# 266             3       0      1      0         1           2        3   True
# 267             4       2      0      0         0           0        3  False
# ...           ...     ...    ...    ...       ...         ...      ...    ...
# 260          1304       2      0      0         0           0        2  False
# 1307         1305       0      0      0         1           0        3   True
# 1308         1306       2      0      0         0           0        3  False
# 261          1307       2      0      0         0           0        2  False
# 262          1308       2      1      1         0           3        0  False
#
#       Sex_1  Embarked_0  Embarked_1  Embarked_2  Title_0  Title_1  Title_2  \
# 263    True       False       False        True    False    False     True
# 264   False        True       False       False    False    False    False
# 265   False       False       False        True    False    False    False
# 266   False       False       False        True    False    False    False
# 267    True       False       False        True    False    False     True
# ...     ...         ...         ...         ...      ...      ...      ...
# 260    True       False       False        True    False    False     True
# 1307  False        True       False       False    False    False    False
# 1308   True       False       False        True    False    False     True
# 261    True       False       False        True    False    False     True
# 262    True        True       False       False    False    False    False
#
#       Title_3  Title_4  Title_5  Title_6  Survived
# 263     False    False    False    False       0.0
# 264      True    False    False    False       1.0
# 265     False     True    False    False       1.0
# 266      True    False    False    False       1.0
# 267     False    False    False    False       0.0
# ...       ...      ...      ...      ...       ...
# 260     False    False    False    False       NaN
# 1307    False    False     True    False       NaN
# 1308    False    False    False    False       NaN
# 261     False    False    False    False       NaN
# 262     False    False     True    False       NaN
#
# [1309 rows x 20 columns]
#       PassengerId  Pclass  SibSp  Parch  Fare_Bin  Num_family  Age_Bin  Sex_0  \
# 977           892       2      0      0         0           0        3  False
# 978           893       2      1      0         0           2        4   True
# 979           894       1      0      0         0           0        6  False
# 980           895       2      0      0         0           0        2  False
# 981           896       2      1      1         0           3        2   True
# ...           ...     ...    ...    ...       ...         ...      ...    ...
# 260          1305       2      0      0         0           0        2  False
# 1307         1306       0      0      0         1           0        3   True
# 1308         1307       2      0      0         0           0        3  False
# 261          1308       2      0      0         0           0        2  False
# 262          1309       2      1      1         0           3        0  False
#
#       Sex_1  Embarked_0  Embarked_1  Embarked_2  Title_0  Title_1  Title_2  \
# 977    True       False        True       False    False    False     True
# 978   False       False       False        True    False    False    False
# 979    True       False        True       False    False    False     True
# 980    True       False       False        True    False    False     True
# 981   False       False       False        True    False    False    False
# ...     ...         ...         ...         ...      ...      ...      ...
# 260    True       False       False        True    False    False     True
# 1307  False        True       False       False    False    False    False
# 1308   True       False       False        True    False    False     True
# 261    True       False       False        True    False    False     True
# 262    True        True       False       False    False    False    False
#
#       Title_3  Title_4  Title_5  Title_6  Survived
# 977     False    False    False    False       NaN
# 978      True    False    False    False       NaN
# 979     False    False    False    False       NaN
# 980     False    False    False    False       NaN
# 981      True    False    False    False       NaN
# ...       ...      ...      ...      ...       ...
# 260     False    False    False    False       NaN
# 1307    False    False     True    False       NaN
# 1308    False    False    False    False       NaN
# 261     False    False    False    False       NaN
# 262     False    False     True    False       NaN
#
# [418 rows x 20 columns]

# %%
# data_pd = pd.read_csv('titanic_preprocessed.csv')
# data_pd.set_index("index",inplace=True)
data_pd = data_pd.dropna(subset=['Survived'])
X_pd = data_pd.drop(columns = ['Survived','PassengerId'])
y_pd = data_pd['Survived']
X_pd,y_pd
# Out:
# (     Pclass  SibSp  Parch  Fare_Bin  Num_family  Age_Bin  Sex_0  Sex_1  \
#  263       2      1      0         0           2        2  False   True
#  264       0      1      0         1           2        3   True  False
#  265       2      0      0         0           0        2   True  False
#  266       0      1      0         1           2        3   True  False
#  267       2      0      0         0           0        3  False   True
#  ..      ...    ...    ...       ...         ...      ...    ...    ...
#  973       1      0      0         0           0        2  False   True
#  974       0      0      0         1           0        1   True  False
#  176       2      1      2         0           4        0   True  False
#  975       0      0      0         1           0        2  False   True
#  976       2      0      0         0           0        3  False   True
#
#       Embarked_0  Embarked_1  Embarked_2  Title_0  Title_1  Title_2  Title_3  \
#  263       False       False        True    False    False     True    False
#  264        True       False       False    False    False    False     True
#  265       False       False        True    False    False    False    False
#  266       False       False        True    False    False    False     True
#  267       False       False        True    False    False     True    False
#  ..          ...         ...         ...      ...      ...      ...      ...
#  973       False       False        True    False    False    False    False
#  974       False       False        True    False    False    False    False
#  176       False       False        True    False    False    False    False
#  975        True       False       False    False    False     True    False
#  976       False        True       False    False    False     True    False
#
#       Title_4  Title_5  Title_6
#  263    False    False    False
#  264    False    False    False
#  265     True    False    False
#  266    False    False    False
#  267    False    False    False
#  ..       ...      ...      ...
#  973    False    False     True
#  974     True    False    False
#  176     True    False    False
#  975    False    False    False
#  976    False    False    False
#
#  [891 rows x 18 columns],
#  263    0.0
#  264    1.0
#  265    1.0
#  266    1.0
#  267    0.0
#        ...
#  973    0.0
#  974    1.0
#  176    0.0
#  975    1.0
#  976    0.0
#  Name: Survived, Length: 891, dtype: float64)

# %% [markdown]
# split the data

# %%
# split
X = X_pd.values
y = y_pd.values

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

print(len(X_scaled))
print(len(y))

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state= 42)
# Out:
# 891
# 891

# %% [markdown]
# RandomForest

# %%
# initialize RandomForestClassifier
rf_clf = RandomForestClassifier()

rf_param_grid = {
    'n_estimators': [100, 200 ,300],
    'max_depth': [2, 3, 5],
    'min_samples_split': [2, 3, 4]
}

rf_grid_search = GridSearchCV(rf_clf, rf_param_grid, cv=3, scoring='f1')

start_time = time.time()
rf_grid_search.fit(X_train, y_train)
rf_time = time.time() - start_time

rf_best = rf_grid_search.best_estimator_

rf_y_pred = rf_best.predict(X_test)
rf_y_train = rf_best.predict(X_train)

rf_train_accuracy = accuracy_score(y_train, rf_y_train)
rf_test_accuracy = accuracy_score(y_test, rf_y_pred)
rf_f1 = f1_score(y_test, rf_y_pred)

print(f"Random Forest best parameters: {rf_grid_search.best_params_}")
print(f"Random Forest best F1 score: {rf_grid_search.best_score_}")
print(f"Random Forest Train accuracy: {rf_train_accuracy}")
print(f"Random Forest Test accuracy: {rf_test_accuracy}")
print(f"Random Forest run time: {rf_time}")
# Out:
# Random Forest best parameters: {'max_depth': 5, 'min_samples_split': 3, 'n_estimators': 300}
# Random Forest best F1 score: 0.7669265296480038
# Random Forest Train accuracy: 0.8412921348314607
# Random Forest Test accuracy: 0.8212290502793296
# Random Forest run time: 5.460580348968506

# %% [markdown]
# XGBoost

# %%
xgb_clf = xgb.XGBClassifier()

xgb_param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 4, 5]
}

xgb_grid_search = GridSearchCV(xgb_clf, xgb_param_grid, cv=3, scoring='f1')

start_time = time.time()
xgb_grid_search.fit(X_train, y_train)
xgb_time = time.time() - start_time

xgb_best = xgb_grid_search.best_estimator_

xgb_y_train = xgb_best.predict(X_train)
xgb_y_pred = xgb_best.predict(X_test)

xgb_train_accuracy = accuracy_score(y_train, xgb_y_train)
xgb_test_accuracy = accuracy_score(y_test, xgb_y_pred)
xgb_f1 = f1_score(y_test, xgb_y_pred)

print(f"XGBoost best parameters: {xgb_grid_search.best_params_}")
print(f"XGBoost best F1 score: {xgb_grid_search.best_score_}")
print(f"XGBoost Train accuracy: {xgb_train_accuracy}")
print(f"XGBoost Test accuracy: {xgb_test_accuracy}")
print(f"XGBoost run time: {xgb_time}")
# Out:
# XGBoost best parameters: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100}
# XGBoost best F1 score: 0.7531441717791411
# XGBoost Train accuracy: 0.8609550561797753
# XGBoost Test accuracy: 0.8324022346368715
# XGBoost run time: 3.452707052230835

# %% [markdown]
# AdamBoost

# %%
ada_clf = AdaBoostClassifier(n_estimators=100, random_state=42)

ada_param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0]
}

ada_grid_search = GridSearchCV(estimator=ada_clf, param_grid=ada_param_grid, cv=5, scoring='accuracy')

start_time = time.time()
ada_grid_search.fit(X_train, y_train)
ada_time = time.time() - start_time

#find the best model
ada_best = ada_grid_search.best_estimator_

# predict with the best model
ada_y_pred = ada_best.predict(X_test)

ada_accuracy = accuracy_score(y_test, ada_y_pred)
ada_f1 = f1_score(y_test, ada_y_pred)

print(f"AdaBoost best parameters: {ada_grid_search.best_params_}")
print(f"AdaBoost best F1 score: {ada_grid_search.best_score_}")
print(f"AdaBoost accuracy: {ada_accuracy}")
print(f"AdaBoost run time: {ada_time}")
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoost best parameters: {'learning_rate': 0.1, 'n_estimators': 100}
# AdaBoost best F1 score: 0.8342361863488623
# AdaBoost accuracy: 0.8156424581005587
# AdaBoost run time: 2.572632312774658
# /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %% [markdown]
# KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN_clf = KNeighborsClassifier(n_neighbors=5)
KNN_clf.fit(X_train, y_train).score(X_test, y_test)

KNN_params = {
    'n_neighbors': range(1,31),
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'p': [1, 2],
}
KNN_grid_search = GridSearchCV(KNN_clf, KNN_params, scoring='accuracy', cv=5)

start_time = time.time()
KNN_grid_search.fit(X_train, y_train)
KNN_time = time.time() - start_time

KNN_best = KNN_grid_search.best_estimator_

KNN_y_train = KNN_best.predict(X_train)
KNN_y_pred = KNN_best.predict(X_test)

KNN_train_accuracy = accuracy_score(y_train, KNN_y_train)
KNN_test_accuracy = accuracy_score(y_test, KNN_y_pred)
KNN_f1 = f1_score(y_test, KNN_y_pred)

print(f"KNN best parameters: {KNN_grid_search.best_params_}")
print(f"KNN best F1 score: {KNN_grid_search.best_score_}")
print(f"KNN Train accuracy: {KNN_train_accuracy}")
print(f"KNN Test accuracy: {KNN_test_accuracy}")
print(f"KNN run time: {KNN_time}")
# Out:
# KNN best parameters: {'algorithm': 'ball_tree', 'n_neighbors': 18, 'p': 1, 'weights': 'uniform'}
# KNN best F1 score: 0.8342854328769821
# KNN Train accuracy: 0.8455056179775281
# KNN Test accuracy: 0.8044692737430168
# KNN run time: 4.751708745956421

# %%
X_test_scaled = scaler.transform(test_pd_tmp)

# use random forest model to predict the suvivors in test.csv
test_predictions = random_forest_model.predict(X_test_scaled)

len(test_predictions)
# print(test_predictions)

result_randomforest = pd.DataFrame({'PassengerId': test_pd['PassengerId'], 'Survived': test_predictions.astype(int)})

result_randomforest.to_csv('randomforest_predictions.csv', index=False)
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(

# %%
X_xg_test_scaled = scaler.transform(test_pd_tmp)

# use random forest model to predict the suvivors in test.csv
XG_test_predictions = xgb_clf.predict(X_xg_test_scaled)

result_randomforest = pd.DataFrame({'PassengerId': test_pd['PassengerId'], 'Survived': XG_test_predictions.astype(int)})

result_randomforest.to_csv('xgboost_predictions.csv', index=False)
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(

# %%
X_KNN_test_scaled = scaler.transform(test_pd_tmp)

# use KNN_clf to predict the suvivors in test.csv
KNN_test_predictions = KNN_clf.predict(X_KNN_test_scaled)

result_randomforest = pd.DataFrame({'PassengerId': test_pd['PassengerId'], 'Survived': KNN_test_predictions.astype(int)})

result_randomforest.to_csv('KNN_predictions.csv', index=False)
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
